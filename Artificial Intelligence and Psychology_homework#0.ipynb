# %%
# Problem 1. Make a calculator that can do the following operations
def Function (num1, num2, operator):
    if operator == '+':
        answer = num1 + num2
    elif operator == '-':
        answer = num1 - num2
    elif operator == '*':
        answer = num1 * num2
    elif operator == '/':
        answer = num1 / num2
    elif operator == '%':
        answer = num1 % num2
    return answer

# print(Function(4, 2, '+')) #6
# print(Function(4, 2, '-')) #2
# print(Function(4, 2, '*')) #8
# print(Function(4, 2, '/')) #2.0
# print(Function(4, 2, '%')) #03

# %%
# Problem 2. Countring Frequency
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# A. Make a 10x10 sized array filled with integers [0-9] by using numpy.
arr = np.random.randint(low=0, high=10, size=(10,10))
print(arr)

# B. Count the number of appearances of each integer, and organize it as 'dataframe' or 'series' format by using pandas.
unique, count = np.unique(arr, return_counts=True)
df = pd.DataFrame(count, unique)
print(df)

# C. Make a histogram of frequency of each number by using matplotlib
arr2 = np.concatenate(arr)
print(arr2)
plt.hist(arr2)
plt.show()
# Out:
# [[3 1 7 3 1 3 0 8 8 5]
#  [9 2 1 0 9 4 9 2 1 4]
#  [9 5 8 4 1 0 8 3 4 5]
#  [2 7 2 3 6 4 6 7 5 1]
#  [6 9 2 7 3 7 4 6 7 0]
#  [6 4 8 6 8 5 2 3 9 0]
#  [1 6 8 1 3 7 7 3 7 9]
#  [4 3 1 8 6 9 2 6 3 7]
#  [6 2 7 9 1 3 7 0 6 0]
#  [4 3 0 4 5 7 4 5 7 3]]
#     0
# 0   8
# 1  10
# 2   8
# 3  14
# 4  11
# 5   7
# 6  11
# 7  14
# 8   8
# 9   9
# [3 1 7 3 1 3 0 8 8 5 9 2 1 0 9 4 9 2 1 4 9 5 8 4 1 0 8 3 4 5 2 7 2 3 6 4 6
#  7 5 1 6 9 2 7 3 7 4 6 7 0 6 4 8 6 8 5 2 3 9 0 1 6 8 1 3 7 7 3 7 9 4 3 1 8
#  6 9 2 6 3 7 6 2 7 9 1 3 7 0 6 0 4 3 0 4 5 7 4 5 7 3]

# %%
# Problem 3. Sorting Problem
arr = np.random.randint(low = 0, high = 10000, size=1000)
print(arr)

sorting_array = [10001]
for i in arr:
    for j in range(len(sorting_array)):
        if i <= sorting_array[j]:
            sorting_array.insert(j, i)
            break
del sorting_array[1000]

#print(sorting_array)
#print(len(sorting_array))
# Out:
# [4946  510 1092 4574 7134 7829 8086 5933  352 5780 8578 7765 9633 1348
#  7085 6372 2586 5080 6084 9949 9145 7297 9340 1052 1347 5828  935 3603
#   228  260 3653 3177 7804 1755 3354  733 3617 3000 4149 9623 8906 4727
#  3255 3610 3562 6186 8974 3565 1455 4153 2402 6103 8858 9614 6506 3319
#  7970 4447 4001 3428  580 9954 7442 9316 5037 4271 3015 7784 9871 5736
#  6152 5137 9163 2586 8929 4834 3922 5054   46  892 1777   31 5332 5440
#  8234 2154 1459 6705 6243 4575 4930 6795 7307 1369 1979 8144 9999 1548
#  6070 6478 6213 1127 9551 1466 5070 9418 3588 7570 1897 6783 2813 7666
#  8109 6517 7001 5145 4115 9315 6932 3161 2980 7340 8621 2721 6275 6736
#  5324 9833   42  516 6385 9781 5920 4629 4371 2473 3641 2914 3710 6097
#   974 6978  159 1270 8775 2613 4218 7969 6905 2125 3954 2623 3424 9152
#  6341   93 6128  280 5100 5944 6549  612 6545 8395 2206 9949 4946 9961
#  7247 7578 9931 3603 7305 4125 5355 8071 9821 7478 5098  507 3287 8398
# ...
